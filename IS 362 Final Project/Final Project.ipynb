# %%
import pandas as pd
import matplotlib.pyplot as plt

'/Understanding the data/'

df = pd.read_csv('wages_by_education.csv')
df.head()
# Out:
#    year  less_than_hs  high_school  some_college  bachelors_degree  \
# 0  2022         16.52        21.94         24.81             41.60
# 1  2021         16.74        22.28         24.92             41.32
# 2  2020         17.02        22.70         25.44             41.65
# 3  2019         16.11        21.64         24.00             39.61
# 4  2018         15.94        21.50         23.70             38.87
#
#    advanced_degree  men_less_than_hs  men_high_school  men_some_college  \
# 0            53.22             17.99            24.08             27.96
# 1            53.45             18.34            24.36             27.96
# 2            53.74             18.76            25.09             28.55
# 3            51.57             17.55            23.99             26.99
# 4            51.03             17.70            23.72             26.61
#
#    men_bachelors_degree  ...  black_women_less_than_hs  \
# 0                 49.01  ...                     13.89
# ...

# %%
df.shape
# Out:
# (50, 61)

# %%
df.dtypes
# Out:
# year                                 int64
# less_than_hs                       float64
# high_school                        float64
# some_college                       float64
# bachelors_degree                   float64
#                                     ...
# hispanic_women_less_than_hs        float64
# hispanic_women_high_school         float64
# hispanic_women_some_college        float64
# hispanic_women_bachelors_degree    float64
# hispanic_women_advanced_degree     float64
# Length: 61, dtype: object

# %%
df.columns
# Out:
# Index(['year', 'less_than_hs', 'high_school', 'some_college',
#        'bachelors_degree', 'advanced_degree', 'men_less_than_hs',
#        'men_high_school', 'men_some_college', 'men_bachelors_degree',
#        'men_advanced_degree', 'women_less_than_hs', 'women_high_school',
#        'women_some_college', 'women_bachelors_degree', 'women_advanced_degree',
#        'white_less_than_hs', 'white_high_school', 'white_some_college',
#        'white_bachelors_degree', 'white_advanced_degree', 'black_less_than_hs',
#        'black_high_school', 'black_some_college', 'black_bachelors_degree',
#        'black_advanced_degree', 'hispanic_less_than_hs',
#        'hispanic_high_school', 'hispanic_some_college',
#        'hispanic_bachelors_degree', 'hispanic_advanced_degree',
#        'white_men_less_than_hs', 'white_men_high_school',
#        'white_men_some_college', 'white_men_bachelors_degree',
#        'white_men_advanced_degree', 'black_men_less_than_hs',
# ...

# %%
'/Cleaning the data/'
df.isnull().sum()
# Out:
# year                               0
# less_than_hs                       0
# high_school                        0
# some_college                       0
# bachelors_degree                   0
#                                   ..
# hispanic_women_less_than_hs        0
# hispanic_women_high_school         0
# hispanic_women_some_college        0
# hispanic_women_bachelors_degree    0
# hispanic_women_advanced_degree     0
# Length: 61, dtype: int64

# %%
'/ US Hourly Wage for the past 50 years/'

axes = plt.gca()
plt.title("Men Hourly Wage Based on Education from 1973 to 2022") 
df.plot(kind='line', x='year', y='men_less_than_hs', ax=axes);
df.plot(kind='line', x='year', y='men_high_school', ax=axes);
df.plot(kind='line', x='year', y='men_some_college', ax=axes);
df.plot(kind='line', x='year', y='men_bachelors_degree', ax=axes);
df.plot(kind='line', x='year', y='men_advanced_degree', ax=axes);

# %%
axes = plt.gca()
plt.title("Women Hourly Wage Based on Education from 1973 to 2022") 
df.plot(kind='line', x='year', y='women_less_than_hs', ax=axes);
df.plot(kind='line', x='year', y='women_high_school', ax=axes);
df.plot(kind='line', x='year', y='women_some_college', ax=axes);
df.plot(kind='line', x='year', y='women_bachelors_degree', ax=axes);
df.plot(kind='line', x='year', y='women_advanced_degree', ax=axes);

# %%
'/ US Hourly Wage by gender/'

selected_years = [1982, 1992, 2002, 2012, 2022]
df_selected_years = df[df['year'].isin(selected_years)]
df_selected_years[['year', 'men_high_school', 'women_high_school']].sort_values(by='year').plot(x='year', kind='bar')
plt.title('Hourly Wage after a High School Degree Based on Gender')
plt.xlabel('Year')
plt.ylabel('Hourly Wage ($)')
plt.show()

# %%
selected_years = [1982, 1992, 2002, 2012, 2022]
df_selected_years = df[df['year'].isin(selected_years)]
df_selected_years[['year', 'men_bachelors_degree', 'women_bachelors_degree']].sort_values(by='year').plot(x='year', kind='bar')
plt.title('Hourly Wage after a Bachelor Degree Based on Gender')
plt.xlabel('Year')
plt.ylabel('Hourly Wage ($)')
plt.show()

# %%
selected_years = [1982, 1992, 2002, 2012, 2022]
df_selected_years = df[df['year'].isin(selected_years)]
df_selected_years[['year', 'men_advanced_degree', 'women_advanced_degree']].sort_values(by='year').plot(x='year', kind='bar')
plt.title('Hourly Wage after an Advanced Degree Based on Gender')
plt.xlabel('Year')
plt.ylabel('Hourly Wage ($)')
plt.show()

# %%
'/ US Hourly Wage by race/'

selected_years = [1982, 1992, 2002, 2012, 2022]
df_selected_years = df[df['year'].isin(selected_years)]
df_selected_years[['year', 'black_high_school', 'hispanic_high_school', 'white_high_school']].sort_values(by='year').plot(x='year', kind='bar')
plt.title('Hourly Wage after a High School Degree Based on Race')
plt.xlabel('Year')
plt.ylabel('Hourly Wage ($)')
plt.show()
